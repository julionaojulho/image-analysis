# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from my_modules.inthei import imread_x

# %%
location = r'\Alta\30\253\Imagem '
ROI = (0,792,64,65)
imgs = np.zeros((1,792))
for i in np.linspace(1,3000,3000):
    a = imread_x(i,location,ROI).T
    imgs = np.concatenate((imgs,a))

# %%
a.shape,imgs.shape
plt.figure(figsize=(10,6))
plt.imshow(imgs.T,cmap=plt.cm.gray)
